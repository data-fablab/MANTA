# %% [markdown]
# # 01 -- Mission, Propulsion & Mass Budget
#
# Complete mission definition with:
# 1. Flight conditions & propulsion model
# 2. Avionics Bill of Materials
# 3. Component placement validation (with duct clearance)
# 4. Electrical power budget
# 5. Complete mass budget (all components accounted)

# %%
import sys
sys.path.insert(0, "..")

import numpy as np
import matplotlib.pyplot as plt

from src.config import load_all
from src.propulsion.edf_model import (
    EDF_70MM, EDF_90MM, BATTERY_3S_1300, BATTERY_3S_800, BATTERY_4S_1000,
    thrust_at_speed, thrust_curve, power_required, endurance,
    intake_drag,
)
from src.parameterization.design_variables import min_body_chord_for_duct
from src.aero.mission import MissionCondition, FeasibilityConfig

from src.visualization.style import apply_style, COLORS
apply_style()

cfg = load_all()
print(f"Config loaded: MTOW={cfg['mission'].mtow} kg")
# %load_ext autoreload
# %autoreload 2
# Out:
# Config loaded: MTOW=2.5 kg

# %% [markdown]
# ## 1. Mission Parameters

# %%
mission = cfg['mission']

print("═══ Mission Condition ═══")
print(f"  Cruise speed   : {mission.velocity} m/s")
print(f"  Altitude       : {mission.altitude} m")
print(f"  MTOW           : {mission.mtow} kg")
print(f"  Weight         : {mission.weight:.2f} N")
print(f"  Density        : {mission.density:.4f} kg/m³")
print(f"  Dynamic press. : {mission.dynamic_pressure:.2f} Pa")
print(f"  Kin. viscosity : {mission.kinematic_viscosity:.2e} m²/s")
print()
print("═══ Mass Budget ═══")
print(f"  Battery        : {mission.battery_mass:.3f} kg ({mission.battery.name})")
print(f"  Motor (EDF)    : {mission.motor_mass:.3f} kg ({mission.edf.name})")
print(f"  Avionics       : {mission.avionics_mass:.3f} kg")
print(f"  ─────────────────────────────")
print(f"  Airframe budget: {mission.mass_budget:.3f} kg")
print()
print("═══ Propulsion ═══")
print(f"  EDF            : {mission.edf.name}")
print(f"  Fan diameter   : {mission.edf.fan_diameter*1000:.0f} mm")
print(f"  Duct OD        : {mission.edf.duct_outer_diameter*1000:.0f} mm")
print(f"  T_static       : {mission.edf.thrust_static:.1f} N")
print(f"  T @ cruise     : {thrust_at_speed(mission.edf, mission.velocity):.2f} N")
print(f"  Battery energy : {mission.battery.energy_wh:.1f} Wh ({mission.battery.energy_j:.0f} J)")

# Thrust direction verification
from src.parameterization.design_variables import BWBParams
from src.propulsion.duct_geometry import DuctSpine, size_and_place_duct
_placement = size_and_place_duct(BWBParams(), mission.edf)
_spine = DuctSpine(_placement)
print(f"  Nozzle exit angle (physical): {_spine.exhaust_angle_physical_deg():.2f}° (0° = thrust // fuselage axis)")
print(f"  Body twist comp. : {_placement.body_twist_deg:.1f}° (compensated in nozzle Bezier)")
# Out:
# ═══ Mission Condition ═══
#   Cruise speed   : 25.0 m/s
#   Altitude       : 100.0 m
#   MTOW           : 2.5 kg
#   Weight         : 24.53 N
#   Density        : 1.2132 kg/m³
#   Dynamic press. : 379.13 Pa
#   Kin. viscosity : 1.47e-05 m²/s
#
# ═══ Mass Budget ═══
#   Battery        : 0.150 kg (3S 1800mAh LiPo)
#   Motor (EDF)    : 0.060 kg (EDF 70mm (Schubeler DS-51 class))
#   Avionics       : 0.179 kg
#   ─────────────────────────────
#   Airframe budget: 1.812 kg
#
# ═══ Propulsion ═══
#   EDF            : EDF 70mm (Schubeler DS-51 class)
#   Fan diameter   : 70 mm
#   Duct OD        : 78 mm
#   T_static       : 10.0 N
#   T @ cruise     : 3.96 N
#   Battery energy : 19.5 Wh (70200 J)
#   Nozzle exit angle (physical): -0.07° (0° = thrust // fuselage axis)
#   Body twist comp. : 2.0° (compensated in nozzle Bezier)

# %% [markdown]
# ## 2. EDF Thrust Curve
#
# The EDF produces maximum thrust at zero speed and decreasing thrust as airspeed increases.
# We use a conservative linear model: `T(V) = T_static × (1 - V/V_max)`.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))

# Thrust curves for both EDF sizes
for edf, color, ls in [(EDF_70MM, "steelblue", "-"), (EDF_90MM, "coral", "--")]:
    v, t = thrust_curve(edf)
    axes[0].plot(v, t, color=color, ls=ls, lw=2, label=edf.name)

# Drag lines for different L/D values (at MTOW=1kg)
W = mission.weight
S_ref_typical = 0.35  # m² typical wing area
for ld_val in [10, 15, 20, 25]:
    D = W / ld_val
    axes[0].axhline(D, color="gray", ls=":", alpha=0.5)
    axes[0].text(1, D + 0.02, f"L/D={ld_val}", fontsize=8, color="gray")

axes[0].axvline(mission.velocity, color="green", ls="--", alpha=0.7, label=f"V_cruise={mission.velocity} m/s")
axes[0].set_xlabel("Airspeed [m/s]")
axes[0].set_ylabel("Thrust / Drag [N]")
axes[0].set_title("EDF Thrust vs Required Drag")
axes[0].legend(fontsize=8)
axes[0].set_xlim(0, 40)
axes[0].set_ylim(0, 25)
axes[0].grid(True, alpha=0.3)

# T/D ratio at cruise for different L/D
ld_range = np.linspace(5, 30, 100)
D_range = W / ld_range
T_avail = thrust_at_speed(EDF_70MM, mission.velocity)
td_ratio = T_avail / D_range

axes[1].plot(ld_range, td_ratio, "steelblue", lw=2)
axes[1].axhline(1.2, color="red", ls="--", lw=1.5, label="T/D = 1.2 (min)")
axes[1].axhline(1.0, color="darkred", ls="-", lw=1, alpha=0.5, label="T/D = 1.0 (no margin)")
axes[1].fill_between(ld_range, 0, 1.2, alpha=0.1, color="red")
axes[1].set_xlabel("L/D")
axes[1].set_ylabel("T/D ratio at cruise")
axes[1].set_title(f"Thrust Margin vs Aerodynamic Efficiency (V={mission.velocity} m/s)")
axes[1].legend(fontsize=8)
axes[1].set_xlim(5, 30)
axes[1].set_ylim(0, 10)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"T_available @ {mission.velocity} m/s = {T_avail:.2f} N")
print(f"Max drag for T/D>1.2 : {T_avail/1.2:.2f} N → min L/D = {W/(T_avail/1.2):.1f}")
# Out:
# T_available @ 25.0 m/s = 3.96 N
# Max drag for T/D>1.2 : 3.30 N → min L/D = 7.4

# %% [markdown]
# ## 3. Endurance & Range vs L/D
#
# For a given L/D, we can compute the total drag, power required, and flight time.
# This is the key trade: higher L/D → less drag → less power → longer flight.

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4.5))

ld_range = np.linspace(5, 30, 200)
batteries = [
    (BATTERY_3S_800, "3S 800mAh", "steelblue", "-"),
    (BATTERY_3S_1300, "3S 1300mAh", "coral", "-"),
    (BATTERY_4S_1000, "4S 1000mAh", "forestgreen", "--"),
]

for batt, label, color, ls in batteries:
    endurance_min = []
    range_km = []
    p_elec = []
    for ld in ld_range:
        D = W / ld
        result = endurance(D, mission.velocity, EDF_70MM, batt)
        endurance_min.append(result["endurance_min"])
        range_km.append(result["range_km"])
        p_elec.append(result["P_elec"])

    axes[0].plot(ld_range, endurance_min, color=color, ls=ls, lw=2, label=label)
    axes[1].plot(ld_range, range_km, color=color, ls=ls, lw=2, label=label)
    axes[2].plot(ld_range, p_elec, color=color, ls=ls, lw=2, label=label)

# Endurance
axes[0].axhline(10, color="red", ls="--", alpha=0.7, label="10 min (min)")
axes[0].set_xlabel("L/D")
axes[0].set_ylabel("Endurance [min]")
axes[0].set_title("Flight Endurance")
axes[0].legend(fontsize=7)
axes[0].set_ylim(0, 60)
axes[0].grid(True, alpha=0.3)

# Range
axes[1].set_xlabel("L/D")
axes[1].set_ylabel("Range [km]")
axes[1].set_title("Flight Range")
axes[1].legend(fontsize=7)
axes[1].grid(True, alpha=0.3)

# Power
axes[2].set_xlabel("L/D")
axes[2].set_ylabel("Electrical Power [W]")
axes[2].set_title("Power Required")
axes[2].legend(fontsize=7)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Reference point: L/D = 20 with default battery
D_ref = W / 20
result_ref = endurance(D_ref, mission.velocity, EDF_70MM, BATTERY_3S_1300)
print(f"Reference point (L/D=20, 3S 1300mAh):")
print(f"  Drag        = {D_ref:.3f} N")
print(f"  P_thrust    = {result_ref['P_thrust']:.1f} W")
print(f"  P_shaft     = {result_ref['P_shaft']:.1f} W")
print(f"  P_elec      = {result_ref['P_elec']:.1f} W")
print(f"  T/D         = {result_ref['T_over_D']:.2f}")
print(f"  Endurance   = {result_ref['endurance_min']:.1f} min")
print(f"  Range       = {result_ref['range_km']:.1f} km")
# Out:
# Reference point (L/D=20, 3S 1300mAh):
#   Drag        = 1.226 N
#   P_thrust    = 30.7 W
#   P_shaft     = 55.7 W
#   P_elec      = 65.6 W
#   T/D         = 3.23
#   Endurance   = 9.2 min
#   Range       = 13.9 km

# %% [markdown]
# ## 4. Geometric Constraints — Duct Fit & Intake Drag
#
# The EDF duct (78 mm OD) must fit inside the BWB center body.
# The semi-circular lip scoop intake adds a small drag increment.

# %%
fig, ax = plt.subplots(figsize=(8, 5))

body_chords = np.linspace(0.30, 1.00, 200)  # body chord [m]
tc_values = [0.12, 0.15, 0.18, 0.20, 0.25]

for tc in tc_values:
    available_h = tc * body_chords * 0.80 * 1000  # [mm]
    ax.plot(body_chords * 1000, available_h, lw=1.5, label=f"t/c = {tc:.0%}")

# Duct diameter lines
ax.axhline(EDF_70MM.duct_outer_diameter * 1000, color="red", ls="--", lw=2,
           label=f"EDF 70mm duct ({EDF_70MM.duct_outer_diameter*1000:.0f}mm)")
ax.axhline(EDF_90MM.duct_outer_diameter * 1000, color="darkred", ls=":", lw=2,
           label=f"EDF 90mm duct ({EDF_90MM.duct_outer_diameter*1000:.0f}mm)")

# Min body chord line
bc_min = min_body_chord_for_duct(EDF_70MM.duct_outer_diameter)
ax.axvline(bc_min * 1000, color="orange", ls="-.", lw=2, label=f"Min body chord ({bc_min*1000:.0f}mm)")

ax.set_xlabel("Body chord [mm]")
ax.set_ylabel("Available height [mm]")
ax.set_title("Body Height vs EDF Duct Diameter")
ax.legend(fontsize=8)
ax.grid(True, alpha=0.3)
ax.set_xlim(300, 1000)
ax.set_ylim(0, 200)

plt.tight_layout()
plt.show()

# Show minimum body chord for duct fit
print(f"Minimum body chord for EDF 70mm: {bc_min*1000:.0f} mm")
print("Body t/c at fan station (x/c=0.40) for different body chords:")
for chord in [0.40, 0.50, 0.60, 0.70]:
    min_tc = EDF_70MM.duct_outer_diameter / (chord * 0.80)
    print(f"  chord={chord*1000:.0f}mm → min t/c = {min_tc:.1%}  "
          f"(t/c=18% {'OK' if 0.18 >= min_tc else 'FAIL'})")
S_ref_range = np.linspace(0.20, 0.60, 100)
cd_intake_70 = [intake_drag(EDF_70MM, s) for s in S_ref_range]
cd_intake_90 = [intake_drag(EDF_90MM, s) for s in S_ref_range]

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(S_ref_range, np.array(cd_intake_70) * 1e4, "steelblue", lw=2, label="EDF 70mm")
ax.plot(S_ref_range, np.array(cd_intake_90) * 1e4, "coral", lw=2, label="EDF 90mm")
ax.set_xlabel("Wing reference area S_ref [m²]")
ax.set_ylabel("CD_intake [counts]")
ax.set_title("Intake Drag Increment")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

cd_ref = intake_drag(EDF_70MM, 0.35)
print(f"Intake drag for EDF 70mm, S_ref=0.35 m²: CD = {cd_ref:.6f} ({cd_ref*1e4:.1f} counts)")
print(f"For comparison, typical wing CD0 ≈ 0.008-0.012 (80-120 counts)")
# Out:
# Minimum body chord for EDF 70mm: 487 mm
# Body t/c at fan station (x/c=0.40) for different body chords:
#   chord=400mm → min t/c = 24.4%  (t/c=18% FAIL)
#   chord=500mm → min t/c = 19.5%  (t/c=18% FAIL)
#   chord=600mm → min t/c = 16.2%  (t/c=18% OK)
#   chord=700mm → min t/c = 13.9%  (t/c=18% OK)
# Intake drag for EDF 70mm, S_ref=0.35 m²: CD = 0.000757 (7.6 counts)
# For comparison, typical wing CD0 ≈ 0.008-0.012 (80-120 counts)

# %% [markdown]
# ## 5. Feasibility Summary
#
# All constraints that will be enforced during optimization:

# %%
fc = cfg['feasibility']

print("═══ Feasibility Constraints ═══")
print()
print("Aerodynamic:")
print(f"  Static margin      : [{fc.sm_min:.0%}, {fc.sm_max:.0%}] MAC  (w_lo={fc.w_sm_lo}, w_hi={fc.w_sm_hi})")
print(f"  |CM| at trim       : < {fc.cm_max}                (w={fc.w_trim})")
print(f"  CL_required        : [{fc.cl_min}, {fc.cl_max}]           (w={fc.w_cl})")
print(f"  Aspect ratio       : > {fc.ar_min}                  (w={fc.w_ar})")
print(f"  Internal volume    : > {fc.volume_min*1e6:.0f} cm³            (w={fc.w_volume})")
print(f"  Cn_beta            : > {fc.cn_beta_min}              (w={fc.w_cn_beta})")
print(f"  Struct mass        : < {mission.mass_budget:.3f} kg        (w={fc.w_mass})")
print()
print("Propulsion:")
print(f"  T/D ratio          : > {fc.td_min}                  (w={fc.w_td})")
print(f"  Endurance          : > {fc.endurance_min:.0f} s ({fc.endurance_min/60:.0f} min)       (w={fc.w_endurance})")
print(f"  Duct bump          : penalized via drag (no hard constraint)")
print()
print("Control / Stability:")
print(f"  Stall speed        : < {fc.vs_max} m/s             (w={fc.w_vs})")
print(f"  Alpha trim         : < {fc.alpha_trim_max}°                (w={fc.w_alpha_trim})")
print(f"  Elevon deflection  : < {fc.elevon_deflection_max}°               (w={fc.w_elevon_defl})")
print(f"  Servo torque       : < {fc.servo_torque_max_kgcm} kg·cm          (w={fc.w_servo_torque})")
print(f"  Manufacturability  : > {fc.manufacturability_min}              (w={fc.w_manufacturability})")
print()
print(f"Total constraints: 13")
# Out:
# ═══ Feasibility Constraints ═══
#
# Aerodynamic:
#   Static margin      : [-5%, 55%] MAC  (w_lo=20.0, w_hi=25.0)
#   |CM| at trim       : < 0.2                (w=15.0)
#   CL_required        : [0.05, 0.75]           (w=10.0)
#   Aspect ratio       : > 4.0                  (w=5.0)
#   Internal volume    : > 800 cm³            (w=15.0)
#   Cn_beta            : > 0.001              (w=15.0)
#   Struct mass        : < 1.812 kg        (w=10.0)
#
# Propulsion:
#   T/D ratio          : > 1.0                  (w=20.0)
#   Endurance          : > 300 s (5 min)       (w=15.0)
#   Duct bump          : penalized via drag (no hard constraint)
#
# Control / Stability:
#   Stall speed        : < 15.0 m/s             (w=20.0)
#   Alpha trim         : < 12.0°                (w=10.0)
#   Elevon deflection  : < 20.0°               (w=15.0)
#   Servo torque       : < 1.3 kg·cm          (w=15.0)
#   Manufacturability  : > 0.2              (w=10.0)
#
# Total constraints: 13

# %% [markdown]
# ## 6. Avionics BOM & Component Placement
#
# Bill of materials and placement validation with duct clearance.

# %%
from src.systems.avionics import AvionicsSpec, print_placement_summary

avionics = AvionicsSpec.default_bwb()
avionics.print_bom()

from src.parameterization.design_variables import BWBParams
print_placement_summary(BWBParams(), avionics)
# Out:
# ================================================================================
#   AVIONICS BILL OF MATERIALS
# ================================================================================
#   Component              Model                    Mass  Power   x/c   Price
#   ----------------------------------------------------------------------
#   FC                     Matek F405-WMN            10g   0.8W  0.28   25.0€
#   Receiver               ELRS EP2 2.4G              2g   0.3W  0.28   15.0€
#   Antenna RC             T-dipole 2.4G              2g      —  0.90    2.0€
#   GPS                    BN-880Q                   10g   0.2W  0.15   12.0€
#   Pitot                  MS4525DO + tube            5g   0.1W  0.05   15.0€
#   ESC                    60A aero (YGE class)      25g      —  0.35   45.0€
#   BEC                    Matek UBEC 5V/5A           5g      —  0.30   10.0€
#   Current sensor         Matek FCHUB-A5             3g      —  0.33    8.0€
#   Servo elevon L         Emax ES3004               17g   2.0W  0.70    8.0€
#   Servo elevon R         Emax ES3004               17g   2.0W  0.70    8.0€
#   Servo aileron L        Emax ES3004               17g   2.0W  0.70    8.0€
#   Servo aileron R        Emax ES3004               17g   2.0W  0.70    8.0€
#   Camera FPV             Caddx Ant Nano             4g   1.2W  0.08   20.0€
#   VTX                    Rush Tiny Tank             5g   1.6W  0.25   25.0€
#   Antenna VTX            Pagoda omni 5.8G           3g      —  0.92    8.0€
#   Buzzer                 5V piezo                   2g      —  0.30    1.0€
#   LED tip L              White 5V LED               1g   0.2W  0.95    1.5€
#   LED tip R              White 5V LED               1g   0.2W  0.95    1.5€
#   Wiring                 22-26 AWG silicone        25g      —  0.35    5.0€
#   Connectors             XT60 + JST + servo         8g      —  0.30    3.0€
#   ----------------------------------------------------------------------
#   TOTAL                                           179g  12.7W        229.0€
#
#
# =====================================================================================
#   COMPONENT PLACEMENT (body chord = 588 mm)
# =====================================================================================
#   Component                x[mm]   z[mm]  H[mm]  Avail   Clr Zone          Fit
#   ----------------------------------------------------------------------
#   FC                       164.6    63.9      6     26    10 above_duct     OK
#   Receiver                 164.6    63.9      5     26    10 above_duct     OK
#   Antenna RC               529.2    13.3      5     50    22 external       OK
#   GPS                       88.2    55.8      8     20     6 above_duct     OK
#   Pitot                     29.4    56.7     10    -34   -22 above_duct   FAIL
#   ESC                      205.8    63.3      8     26     9 above_duct     OK
#   BEC                      176.4    63.9      6     26    10 above_duct     OK
#   Current sensor           194.0    63.7      3     26    12 above_duct     OK
#   Servo elevon L           411.6   -10.6     10     20     5 wing           OK
#   Servo elevon R           411.6   -10.6     10     20     5 wing           OK
#   Servo aileron L          411.6   -10.6     10     20     5 wing           OK
#   Servo aileron R          411.6   -10.6     10     20     5 wing           OK
#   Camera FPV                47.0    53.1     15     -6   -11 above_duct   FAIL
#   VTX                      147.0    63.6      5     25    10 above_duct     OK
#   Antenna VTX              541.0    10.5      5     50    22 external       OK
#   Buzzer                   176.4    63.9      6     26    10 above_duct     OK
#   LED tip L                558.6    -0.6      5     20     8 wing           OK
#   LED tip R                558.6    -0.6      5     20     8 wing           OK
#   ----------------------------------------------------------------------
#   Overall: SOME DO NOT FIT

# %% [markdown]
# ## 7. Power & Mass Budget

# %%
budget = avionics.compute_power_budget()
print(f"Total power: {budget["total_power_w"]:.1f} W")
print(f"BEC current: {budget["bec_current_a"]:.2f} A / {budget["bec_capacity_a"]:.0f} A")
print(f"BEC margin:  {budget["bec_margin_pct"]:.0f}%")

m = mission  # from cell above
print(f"MTOW:           {m.mtow*1000:.0f}g")
print(f"  Battery:      {m.battery_mass*1000:.0f}g")
print(f"  EDF motor:    {m.motor_mass*1000:.0f}g")
print(f"  Avionics:     {m.avionics_mass*1000:.0f}g")
print(f"  Duct struct:  {m.duct_mass*1000:.0f}g")
print(f"  Auxiliaries:  {m.auxiliary_mass*1000:.0f}g")
total_fixed = m.battery_mass + m.motor_mass + m.avionics_mass + m.duct_mass + m.auxiliary_mass
print(f"  ---------------------")
print(f"  Fixed total:  {total_fixed*1000:.0f}g")
print(f"  Struct budget:{m.mass_budget*1000:.0f}g")
print()
if m.mass_budget < 0.5:
    print("WARNING: Structure budget very tight! Consider increasing MTOW or reducing components.")
else:
    print(f"Structure budget OK ({m.mass_budget*1000:.0f}g available)")
# Out:
# Total power: 12.7 W
# BEC current: 2.54 A / 5 A
# BEC margin:  49%
# MTOW:           2500g
#   Battery:      150g
#   EDF motor:    60g
#   Avionics:     179g
#   Duct struct:  19g
#   Auxiliaries:  80g
#   ---------------------
#   Fixed total:  488g
#   Struct budget:1812g
#
# Structure budget OK (1812g available)

# %% [markdown]
# ## 8. Mass Budget Visualization

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# --- Pie chart: MTOW decomposition ---
labels = ['Battery', 'EDF motor', 'Avionics', 'Duct struct.', 'Auxiliaries', 'Structure\n(budget)']
masses = [m.battery_mass, m.motor_mass, m.avionics_mass, m.duct_mass, m.auxiliary_mass, m.mass_budget]
colors = [COLORS['battery'], COLORS['motor'], COLORS['avionics'],
          COLORS['duct'], COLORS['warning'], COLORS['structure']]
explode = [0, 0, 0, 0, 0, 0.05]

wedges, texts, autotexts = ax1.pie(
    masses, labels=labels, colors=colors, explode=explode,
    autopct=lambda p: f'{p*m.mtow*10:.0f}g\n({p:.0f}%)',
    pctdistance=0.75, startangle=90, textprops={'fontsize': 9},
)
for at in autotexts:
    at.set_fontsize(8)
ax1.set_title(f'MTOW Decomposition ({m.mtow*1000:.0f}g)', fontsize=14, fontweight='bold')

# --- Bar chart: component placement along body chord ---
from src.systems.avionics import compute_component_positions_3d
positions = compute_component_positions_3d(BWBParams(), avionics)

# Group by zone
zone_colors = {'forward': COLORS['feasible'], 'above_duct': COLORS['avionics'],
               'wing': COLORS['wing'], 'external': COLORS['secondary']}
for p_info in positions:
    if p_info['mass_g'] < 1:
        continue
    x_mm = p_info['position_mm'][0]
    zone = p_info.get('zone', 'forward')
    color = zone_colors.get(zone, COLORS['secondary'])
    ax2.barh(p_info['name'][:15], p_info['mass_g'], color=color, edgecolor='white', linewidth=0.5)

ax2.set_xlabel('Mass [g]')
ax2.set_title('Component Masses', fontsize=14, fontweight='bold')
ax2.invert_yaxis()

plt.tight_layout()
plt.savefig('../output/mass_budget_overview.png', dpi=150, bbox_inches='tight')
plt.show()
